# %%
import numpy as np
import pandas as pd

# %%
# creating a series
s = pd.Series([1,3,5,np.nan, 6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# Creating a DataFrame by passing a NumPy array with a datetime index and labeled columns

dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.478729  0.153465 -0.426796  1.066073
# 2013-01-02 -0.185653  1.541166 -1.505916  2.357942
# 2013-01-03 -0.890696  0.256382 -0.634050  1.416992
# 2013-01-04  0.818477  1.760214 -1.882426 -0.857340
# 2013-01-05 -2.259242  0.045514 -0.951776  0.246553
# 2013-01-06  1.160918 -0.126257 -0.627073  1.520441

# %%
# Creating a DataFrame by passing a dict of objects that can be converted to series-like.
df2 = pd.DataFrame({'A':1.,
             'B': pd.Timestamp('20130102'),
             'C': pd.Series(1, index=list(range(4)), dtype='float32'), 
             'D': np.array([3] * 4, dtype='int32'), 
             'E': pd.Categorical(["test", "train", "test", "train"]), 
             'F': 'foo'})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -1.478729  0.153465 -0.426796  1.066073
# 2013-01-02 -0.185653  1.541166 -1.505916  2.357942
# 2013-01-03 -0.890696  0.256382 -0.634050  1.416992
# 2013-01-04  0.818477  1.760214 -1.882426 -0.857340
# 2013-01-05 -2.259242  0.045514 -0.951776  0.246553

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  0.818477  1.760214 -1.882426 -0.857340
# 2013-01-05 -2.259242  0.045514 -0.951776  0.246553
# 2013-01-06  1.160918 -0.126257 -0.627073  1.520441

# %%
# Display the index, columns:
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-1.47872889,  0.15346501, -0.426796  ,  1.06607331],
#        [-0.18565345,  1.54116622, -1.5059156 ,  2.3579424 ],
#        [-0.89069615,  0.25638222, -0.63405012,  1.41699157],
#        [ 0.81847709,  1.76021384, -1.8824257 , -0.85734023],
#        [-2.25924242,  0.0455138 , -0.95177597,  0.24655316],
#        [ 1.16091765, -0.12625707, -0.62707324,  1.52044058]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
# quick summary of your data
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.472488  0.605081 -1.004673  0.958443
# std    1.326408  0.822691  0.572429  1.122510
# min   -2.259242 -0.126257 -1.882426 -0.857340
# 25%   -1.331721  0.072502 -1.367381  0.451433
# 50%   -0.538175  0.204924 -0.792913  1.241532
# 75%    0.567444  1.219970 -0.628817  1.494578
# max    1.160918  1.760214 -0.426796  2.357942

# %%
# transposing data
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -1.478729   -0.185653   -0.890696    0.818477   -2.259242    1.160918
# B    0.153465    1.541166    0.256382    1.760214    0.045514   -0.126257
# C   -0.426796   -1.505916   -0.634050   -1.882426   -0.951776   -0.627073
# D    1.066073    2.357942    1.416992   -0.857340    0.246553    1.520441

# %%
# sorting by an axis
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  1.066073 -0.426796  0.153465 -1.478729
# 2013-01-02  2.357942 -1.505916  1.541166 -0.185653
# 2013-01-03  1.416992 -0.634050  0.256382 -0.890696
# 2013-01-04 -0.857340 -1.882426  1.760214  0.818477
# 2013-01-05  0.246553 -0.951776  0.045514 -2.259242
# 2013-01-06  1.520441 -0.627073 -0.126257  1.160918

# %%
# sorting by values
df.sort_values(by='A')
# Out:
#                    A         B         C         D
# 2013-01-05 -2.259242  0.045514 -0.951776  0.246553
# 2013-01-01 -1.478729  0.153465 -0.426796  1.066073
# 2013-01-03 -0.890696  0.256382 -0.634050  1.416992
# 2013-01-02 -0.185653  1.541166 -1.505916  2.357942
# 2013-01-04  0.818477  1.760214 -1.882426 -0.857340
# 2013-01-06  1.160918 -0.126257 -0.627073  1.520441

# %%
# selecting a column
df['A']
# Out:
# 2013-01-01   -1.478729
# 2013-01-02   -0.185653
# 2013-01-03   -0.890696
# 2013-01-04    0.818477
# 2013-01-05   -2.259242
# 2013-01-06    1.160918
# Freq: D, Name: A, dtype: float64

# %%
# selecting via [] which slices the rows
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -1.478729  0.153465 -0.426796  1.066073
# 2013-01-02 -0.185653  1.541166 -1.505916  2.357942
# 2013-01-03 -0.890696  0.256382 -0.634050  1.416992

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02 -0.185653  1.541166 -1.505916  2.357942
# 2013-01-03 -0.890696  0.256382 -0.634050  1.416992
# 2013-01-04  0.818477  1.760214 -1.882426 -0.857340

# %%
# selecting by label
df.loc[dates[0]]
# Out:
# A   -1.478729
# B    0.153465
# C   -0.426796
# D    1.066073
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
# selecting on multi-axis by label
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2013-01-01 -1.478729  0.153465
# 2013-01-02 -0.185653  1.541166
# 2013-01-03 -0.890696  0.256382
# 2013-01-04  0.818477  1.760214
# 2013-01-05 -2.259242  0.045514
# 2013-01-06  1.160918 -0.126257

# %%
# showing label slicing, both endpoints are included:
df.loc['20130102':'20130104', ['A', 'B']]
# Out:
#                    A         B
# 2013-01-02 -0.185653  1.541166
# 2013-01-03 -0.890696  0.256382
# 2013-01-04  0.818477  1.760214

# %%
# selection by position
df.iloc[3]
# Out:
# A    0.818477
# B    1.760214
# C   -1.882426
# D   -0.857340
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
# selection by position slices, similar to numpy/python
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  0.818477  1.760214
# 2013-01-05 -2.259242  0.045514

# %%
# selection by lists of integer position locations, similar to numpy/python
df.iloc[[1,2,4], [0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.185653 -1.505916
# 2013-01-03 -0.890696 -0.634050
# 2013-01-05 -2.259242 -0.951776

# %%
# for slicing rows explicitly
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.185653  1.541166 -1.505916  2.357942
# 2013-01-03 -0.890696  0.256382 -0.634050  1.416992

# %%
# for slicing columns explicitly
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.153465 -0.426796
# 2013-01-02  1.541166 -1.505916
# 2013-01-03  0.256382 -0.634050
# 2013-01-04  1.760214 -1.882426
# 2013-01-05  0.045514 -0.951776
# 2013-01-06 -0.126257 -0.627073

# %%
# for getting a value explicitly
df.iloc[1,1]
# Out:
# 1.5411662172438891

# %%
# Boolean indexing, using a single column's values to select data
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-04  0.818477  1.760214 -1.882426 -0.857340
# 2013-01-06  1.160918 -0.126257 -0.627073  1.520441

# %%
# Selecting values from a DataFrame where a boolean condition is met
df[df > 0]
# Out:
#                    A         B   C         D
# 2013-01-01       NaN  0.153465 NaN  1.066073
# 2013-01-02       NaN  1.541166 NaN  2.357942
# 2013-01-03       NaN  0.256382 NaN  1.416992
# 2013-01-04  0.818477  1.760214 NaN       NaN
# 2013-01-05       NaN  0.045514 NaN  0.246553
# 2013-01-06  1.160918       NaN NaN  1.520441

# %%
# Using the isin() method for filtering:
df2 = df.copy()

df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']

df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -1.478729  0.153465 -0.426796  1.066073    one
# 2013-01-02 -0.185653  1.541166 -1.505916  2.357942    one
# 2013-01-03 -0.890696  0.256382 -0.634050  1.416992    two
# 2013-01-04  0.818477  1.760214 -1.882426 -0.857340  three
# 2013-01-05 -2.259242  0.045514 -0.951776  0.246553   four
# 2013-01-06  1.160918 -0.126257 -0.627073  1.520441  three

# %%
df2[df2['E'].isin(['two', 'four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.890696  0.256382 -0.634050  1.416992   two
# 2013-01-05 -2.259242  0.045514 -0.951776  0.246553  four

# %%
# setting a new column automatically aligns the data by the indexes
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20130102', periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %%
# setting values by label:
df.iat[0,1] = 0

# %%
# setting by assigning with NumPy array:
df.loc[:, 'D'] = np.array([5] * len(df))

df
# Out:
#                    A         B         C  D    F
# 2013-01-01 -1.478729  0.000000 -0.426796  5  NaN
# 2013-01-02 -0.185653  1.541166 -1.505916  5  1.0
# 2013-01-03 -0.890696  0.256382 -0.634050  5  2.0
# 2013-01-04  0.818477  1.760214 -1.882426  5  3.0
# 2013-01-05 -2.259242  0.045514 -0.951776  5  4.0
# 2013-01-06  1.160918 -0.126257 -0.627073  5  5.0

# %%
# a where operation with setting
df2 = df.copy()

df2[df2 > 0] = -df2

df2
# Out:
#                    A         B         C  D    F
# 2013-01-01 -1.478729  0.000000 -0.426796 -5  NaN
# 2013-01-02 -0.185653 -1.541166 -1.505916 -5 -1.0
# 2013-01-03 -0.890696 -0.256382 -0.634050 -5 -2.0
# 2013-01-04 -0.818477 -1.760214 -1.882426 -5 -3.0
# 2013-01-05 -2.259242 -0.045514 -0.951776 -5 -4.0
# 2013-01-06 -1.160918 -0.126257 -0.627073 -5 -5.0

# %%
# Reindexing allows you to change/add/delete the index on a specified axis.
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]]
# Out:
# A   -1.478729
# B    0.000000
# C   -0.426796
# D    5.000000
# F         NaN
# E         NaN
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
# drop any rows that have missing data
df1.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, F, E]
# Index: []

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01 -1.478729  0.000000 -0.426796  5  5.0  5.0
# 2013-01-02 -0.185653  1.541166 -1.505916  5  1.0  5.0
# 2013-01-03 -0.890696  0.256382 -0.634050  5  2.0  5.0
# 2013-01-04  0.818477  1.760214 -1.882426  5  3.0  5.0

# %%
# get the boolean mask where values are nan
pd.isna(df1)
# Out:
#                 A      B      C      D      F     E
# 2013-01-01  False  False  False  False   True  True
# 2013-01-02  False  False  False  False  False  True
# 2013-01-03  False  False  False  False  False  True
# 2013-01-04  False  False  False  False  False  True

# %%
# performing operations
# performing descriptive statistic
df.mean()
# Out:
# A   -0.472488
# B    0.579503
# C   -1.004673
# D    5.000000
# F    3.000000
# dtype: float64

# %%
# operation on other axis
df.mean(1)
# Out:
# 2013-01-01    0.773619
# 2013-01-02    1.169919
# 2013-01-03    1.146327
# 2013-01-04    1.739253
# 2013-01-05    1.166899
# 2013-01-06    2.081517
# Freq: D, dtype: float64

# %%
# Operating with objects that have different dimensionality and need alignment
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis = 'index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.890696 -0.743618 -1.634050  4.0  1.0
# 2013-01-04 -2.181523 -1.239786 -4.882426  2.0  0.0
# 2013-01-05 -7.259242 -4.954486 -5.951776  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
# applying functions to the data
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01 -1.478729  0.000000 -0.426796   5   NaN
# 2013-01-02 -1.664382  1.541166 -1.932712  10   1.0
# 2013-01-03 -2.555078  1.797548 -2.566762  15   3.0
# 2013-01-04 -1.736601  3.557762 -4.449187  20   6.0
# 2013-01-05 -3.995844  3.603276 -5.400963  25  10.0
# 2013-01-06 -2.834926  3.477019 -6.028037  30  15.0

# %%
df.apply(lambda x:x.max() - x.min())
# Out:
# A    3.420160
# B    1.886471
# C    1.455630
# D    0.000000
# F    4.000000
# dtype: float64

# %%
# histogramming
s = pd.Series(np.random.randint(0,7, size=10))
s
# Out:
# 0    6
# 1    5
# 2    5
# 3    2
# 4    3
# 5    4
# 6    2
# 7    4
# 8    0
# 9    0
# dtype: int32

# %%
s.value_counts()
# Out:
# 5    2
# 4    2
# 2    2
# 0    2
# 6    1
# 3    1
# dtype: int64

# %%
# string methods
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
# Concatenating pandas objects together with concat():
df = pd.DataFrame(np.random.randn(10,4))
df
# Out:
#           0         1         2         3
# 0 -0.324181 -1.888520  0.004378  0.256463
# 1  1.814430 -1.853428  0.345344 -0.262629
# 2 -0.118765  0.147070  1.115477  0.100587
# 3  0.271471 -0.764890 -2.523207  0.339510
# 4  1.464345  1.710349 -1.529526 -0.738890
# 5 -0.030683  1.513339  0.064338 -1.325830
# 6  0.220659  0.019912  0.880178  0.091595
# 7  1.275898  0.961123 -0.301526  0.355623
# 8 -0.484604  0.083064 -0.888883 -0.038223
# 9  0.563885 -1.743756  0.319913  1.368473

# %%
# break it to pieces
pieces = [df[:3], df[2:7], df[5:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.324181 -1.888520  0.004378  0.256463
# 1  1.814430 -1.853428  0.345344 -0.262629
# 2 -0.118765  0.147070  1.115477  0.100587
# 2 -0.118765  0.147070  1.115477  0.100587
# 3  0.271471 -0.764890 -2.523207  0.339510
# 4  1.464345  1.710349 -1.529526 -0.738890
# 5 -0.030683  1.513339  0.064338 -1.325830
# 6  0.220659  0.019912  0.880178  0.091595
# 5 -0.030683  1.513339  0.064338 -1.325830
# 6  0.220659  0.019912  0.880178  0.091595
# 7  1.275898  0.961123 -0.301526  0.355623
# 8 -0.484604  0.083064 -0.888883 -0.038223
# 9  0.563885 -1.743756  0.319913  1.368473

# %%
# SQL style mergers
left = pd.DataFrame({'key':['foo', 'foo'], 'Ival':[1,2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  Ival
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  Ival  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
# another example
left = pd.DataFrame({'key':['foo', 'bar'], 'Ival':[1,2]})
right = pd.DataFrame({'key':['foo', 'bar'], 'rval':[4,5]})

# %%
left
# Out:
#    key  Ival
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  Ival  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
# append rows to a dataframe
df = pd.DataFrame(np.random.randn(8,4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  0.262381  0.671250 -1.348413  0.604647
# 1  0.061561  0.554245  0.585718  0.924065
# 2  0.404422  1.515247 -0.622047 -0.621323
# 3 -0.479886 -1.565070 -0.414824  1.860461
# 4 -1.647323 -2.399923 -0.477275 -0.617594
# 5 -0.494690  0.713816  0.637953 -2.250875
# 6  0.659331  1.073960  0.598531  1.517080
# 7 -0.022811  0.959539 -1.122627 -1.279109

# %%
s = df.iloc[3]
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  0.262381  0.671250 -1.348413  0.604647
# 1  0.061561  0.554245  0.585718  0.924065
# 2  0.404422  1.515247 -0.622047 -0.621323
# 3 -0.479886 -1.565070 -0.414824  1.860461
# 4 -1.647323 -2.399923 -0.477275 -0.617594
# 5 -0.494690  0.713816  0.637953 -2.250875
# 6  0.659331  1.073960  0.598531  1.517080
# 7 -0.022811  0.959539 -1.122627 -1.279109
# 8 -0.479886 -1.565070 -0.414824  1.860461

# %% [markdown]
# By “group by” we are referring to a process involving one or more of the following steps:
#
# - Splitting the data into groups based on some criteria
# - Applying a function to each group independently
# - Combining the results into a data structure

# %%
df = pd.DataFrame({'A':['foo', 'bar', 'foo', 'bar', 
                  'foo', 'bar', 'foo', 'foo'], 
             'B':['one', 'one', 'two', 'three', 
                 'two', 'two', 'one', 'three'], 
             'C':np.random.randn(8), 
             'D':np.random.randn(8)})

df
# Out:
#      A      B         C         D
# 0  foo    one  1.850091 -0.185709
# 1  bar    one -1.062701 -1.112217
# 2  foo    two -1.392488  0.207758
# 3  bar  three  1.099330 -0.109059
# 4  foo    two  2.127603  1.115882
# 5  bar    two -0.110723 -0.058515
# 6  foo    one -0.048483  0.636521
# 7  foo  three -0.150854  0.795127

# %%
# Grouping and then applying the sum() function to the resulting groups.
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -0.074094 -1.279792
# foo  2.385868  2.569580

# %%
# Grouping by multiple columns forms a hierarchical index
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -1.062701 -1.112217
#     three  1.099330 -0.109059
#     two   -0.110723 -0.058515
# foo one    1.801608  0.450812
#     three -0.150854  0.795127
#     two    0.735115  1.323640

# %%
# reshaping, stack
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                         'foo', 'foo', 'qux', 'qux'],
                        ['one', 'two', 'one', 'two',
                         'one', 'two', 'one', 'two']]))
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
df = pd.DataFrame(np.random.randn(8,2), index=index, columns=['A', 'B'])
df2 =df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     0.462430 -1.002399
#       two    -1.724002  1.316993
# baz   one    -0.167404 -0.073619
#       two     0.232321  1.475721

# %%
# The stack() method “compresses” a level in the DataFrame’s columns.
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A    0.462430
#                B   -1.002399
#        two     A   -1.724002
#                B    1.316993
# baz    one     A   -0.167404
#                B   -0.073619
#        two     A    0.232321
#                B    1.475721
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.462430 -1.002399
#       two    -1.724002  1.316993
# baz   one    -0.167404 -0.073619
#       two     0.232321  1.475721

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.462430 -1.724002
#       B -1.002399  1.316993
# baz   A -0.167404  0.232321
#       B -0.073619  1.475721

# %%
# pivot table
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
                       'B': ['A', 'B', 'C'] * 4,
                       'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                       'D': np.random.randn(12),
                       'E': np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  2.338050  1.174727
# 1     one  B  foo  0.705119 -1.516826
# 2     two  C  foo -1.286377 -0.359323
# 3   three  A  bar -0.372744 -1.262305
# 4     one  B  bar -0.425457 -0.061096
# 5     one  C  bar  0.337355 -0.316619
# 6     two  A  foo  0.799858  0.670869
# 7   three  B  foo  0.798144 -0.224897
# 8     one  C  foo  0.447151 -0.645814
# 9     one  A  bar -1.022550  0.471620
# 10    two  B  bar  0.771127 -1.244920
# 11  three  C  bar  2.569531 -0.189223

# %%
# pivot data from this table
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -1.022550  2.338050
#       B -0.425457  0.705119
#       C  0.337355  0.447151
# three A -0.372744       NaN
#       B       NaN  0.798144
#       C  2.569531       NaN
# two   A       NaN  0.799858
#       B  0.771127       NaN
#       C       NaN -1.286377

# %%
# time series
rng = pd.date_range('1/1/2012', periods=100, freq='S')
ts = pd.Series(np.random.randint(0,500, len(rng)), index=rng)
ts.resample('5Min').sum()
# Out:
# 2012-01-01    23163
# Freq: 5T, dtype: int32

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)
ts

ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-01-01 00:00:00+00:00   -0.762182
# 2012-01-01 00:00:01+00:00    0.270381
# 2012-01-01 00:00:02+00:00   -0.578241
# 2012-01-01 00:00:03+00:00   -0.929936
# 2012-01-01 00:00:04+00:00   -1.113910
# 2012-01-01 00:00:05+00:00   -0.921004
# 2012-01-01 00:00:06+00:00    1.871574
# 2012-01-01 00:00:07+00:00    0.337585
# 2012-01-01 00:00:08+00:00    0.144002
# 2012-01-01 00:00:09+00:00   -0.494467
# 2012-01-01 00:00:10+00:00    1.482239
# 2012-01-01 00:00:11+00:00    0.390503
# 2012-01-01 00:00:12+00:00    0.621738
# 2012-01-01 00:00:13+00:00   -2.460993
# 2012-01-01 00:00:14+00:00    0.485021
# 2012-01-01 00:00:15+00:00   -0.869436
# 2012-01-01 00:00:16+00:00    0.441770
# 2012-01-01 00:00:17+00:00   -1.451867
# 2012-01-01 00:00:18+00:00    0.278606
# 2012-01-01 00:00:19+00:00   -0.287655
# 2012-01-01 00:00:20+00:00    1.066973
# 2012-01-01 00:00:21+00:00   -0.366167
# 2012-01-01 00:00:22+00:00   -0.030645
# 2012-01-01 00:00:23+00:00    1.070469
# 2012-01-01 00:00:24+00:00    1.097783
# 2012-01-01 00:00:25+00:00   -0.616558
# 2012-01-01 00:00:26+00:00    0.540458
# 2012-01-01 00:00:27+00:00   -0.176484
# 2012-01-01 00:00:28+00:00    0.241046
# 2012-01-01 00:00:29+00:00   -0.917454
#                                ...
# 2012-01-01 00:01:10+00:00   -1.865185
# 2012-01-01 00:01:11+00:00   -0.042619
# 2012-01-01 00:01:12+00:00    0.431168
# 2011-12-31 19:01:12-05:00    0.431168
# 2011-12-31 19:01:13-05:00   -0.470877
# 2011-12-31 19:01:14-05:00   -0.211377
# 2011-12-31 19:01:15-05:00    0.175347
# 2011-12-31 19:01:16-05:00    1.324255
# 2011-12-31 19:01:17-05:00    2.148286
# 2011-12-31 19:01:18-05:00    0.822294
# 2011-12-31 19:01:19-05:00    0.472202
# 2011-12-31 19:01:20-05:00   -0.402091
# 2011-12-31 19:01:21-05:00   -0.659750
# 2011-12-31 19:01:22-05:00    0.230779
# 2011-12-31 19:01:23-05:00   -0.686662
# 2011-12-31 19:01:24-05:00   -1.272195
# 2011-12-31 19:01:25-05:00   -0.727075
# 2011-12-31 19:01:26-05:00    0.484043
# 2011-12-31 19:01:27-05:00    0.887582
# 2011-12-31 19:01:28-05:00   -0.589928
# 2011-12-31 19:01:29-05:00   -0.177553
# 2011-12-31 19:01:30-05:00    0.055752
# 2011-12-31 19:01:31-05:00   -1.586051
# 2011-12-31 19:01:32-05:00   -0.799908
# 2011-12-31 19:01:33-05:00   -1.427943
# 2011-12-31 19:01:34-05:00   -1.101041
# 2011-12-31 19:01:35-05:00   -1.619920
# 2011-12-31 19:01:36-05:00   -1.253769
# 2011-12-31 19:01:37-05:00    1.148106
# 2011-12-31 19:01:38-05:00   -1.044832
# 2011-12-31 19:01:39-05:00   -0.869822
# Freq: S, Length: 100, dtype: float64

# %%
# Converting between time span representations
rng = pd.date_range('1/1/2012', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2012-01-31    0.439477
# 2012-02-29    1.454579
# 2012-03-31   -1.369393
# 2012-04-30   -0.461120
# 2012-05-31   -2.716777
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-01    0.439477
# 2012-02    1.454579
# 2012-03   -1.369393
# 2012-04   -0.461120
# 2012-05   -2.716777
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    0.439477
# 2012-02-01    1.454579
# 2012-03-01   -1.369393
# 2012-04-01   -0.461120
# 2012-05-01   -2.716777
# Freq: MS, dtype: float64

# %%
# categorical data in a DataFrame
df = pd.DataFrame({"id": [1, 2, 3, 4, 5, 6],
                       "raw_grade": ['a', 'b', 'b', 'a', 'a', 'e']})

# convert raw grades to a categorical data type
df['grade'] = df['raw_grade'].astype('category')
df['grade']
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
# Rename the categories to more meaningful names (assigning to Series.cat.categories is inplace!).
df['grade'].cat.categories = ['very good', 'good', 'very bad']

# %%
# Reorder the categories and simultaneously add the missing categories
df['grade'] = df['grade'].cat.set_categories(['very bad', 'bad', 'medium', 'good', 'very good'])
df['grade']
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
# Sorting is per order in the categories, not lexical order.
df.sort_values(by='grade')
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
# Grouping by a categorical column also shows empty categories.
df.groupby('grade').size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
# plotting
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

ts = ts.cumsum()

ts.plot()

# %%
# On a DataFrame, the plot() method is a convenience to plot all of the columns with labels:
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])
df = df.cumsum()

import matplotlib.pyplot as plt

plt.figure()

df.plot()

plt.legend(loc='best')

# %%
# getting data in & out

df.to_csv('foo.csv')

pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0          A          